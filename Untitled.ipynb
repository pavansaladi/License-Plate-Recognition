# %%
test_dir="/home/birla/Downloads/CRNN-Keras/DB/test/"

# %%
import os
test_imgs = os.listdir(test_dir)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2

# %%
for test_img in test_imgs:
    try:
        img = cv2.imread(test_dir + test_img)
    
        print("original_text", test_img[0:-4])

        img_pred = cv2.resize(img, (256,64))
        plt.figure()
        plt.imshow(img_pred)
#         plt.savefig(str(i)+".png")
        plt.show()
        
    except Exception as e:
        print(str(e))
# Out:
# original_text KA 01P 3702
# original_text KA 03JC 3596
# original_text KA 01 HH 2975
# original_text KA 19P 8488
# original_text KA 01 MQ 4910
# original_text KA 02 MF 3965
# original_text KA 35 X 4385
# original_text KA 51 MA 2800
# original_text KA 18M 7152
# original_text KA 04 MV5030
# original_text KA 04 MA 3873
# original_text KA 01 MR 1750
# original_text KA 05 MS 9584
# original_text KA05MS6330
# original_text KA 05 MV 6209
# original_text KA 51 ME 8705
# original_text KA 53 MC 8232
# original_text KA 03 JR 7249
# original_text KA 03 NA 7542
# original_text KA 02 AE 6026
# original_text KA51MH7813
# original_text KA 01 MK 8164
# original_text KA 53 A 5599
# original_text KA 53 MC 7973
# original_text KA 03 MY 5574
# original_text KA 05 MX 0260
# original_text KA 05 JG 7663
# original_text KA 03 MZ 4758
# original_text KA 02 MK 7826
# original_text KA 03JN 8775
# original_text KA 01 HT 3395
# original_text KA03MB8257
# original_text KA 03 NE 8092
# original_text KA20 P 4959
# original_text KA 34 N 3007
# original_text KA 50 EC 0041
# original_text KA 53 MC 6572
# original_text KA 01 MM 6665
# original_text KA 01 EU 1699
# original_text KA 53 ME 6821
# original_text KA 03 MJ 2454
# original_text KA 05KS 3266
# original_text KA 05 MN 3681
# original_text KA  05 KS 9023
# original_text KA 11 W 5044
# original_text KA 03 MU 6307
# original_text KA 05JU 2930
# original_text KA 03 NA 8531
# original_text KA 01JF 3747
# original_text KA 04 MC 5235
# original_text KA 51ME 7833
# original_text KA 03 HT 5390
# original_text KA 53EK 5280
# original_text KA 01 ML 5737
# original_text KA 01 HL 6836
# original_text KA03MN5214
# original_text KA 09 ZZ 9999
# original_text KA03MS7979
# original_text KA46M4399
# original_text KA52M9158
# original_text KA03MN5959
# original_text KA 01 HE 7799
